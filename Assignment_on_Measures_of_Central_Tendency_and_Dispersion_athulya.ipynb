# %% [markdown]
# <a href="https://colab.research.google.com/github/athu-lya/Assignment1/blob/main/Assignment_on_Measures_of_Central_Tendency_and_Dispersion_athulya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# An Institution wishes to find out their student’s ability in mathematics, reading and writing skills. The Institution wants to do an exploratory study to check the following information.

# %%
#uploading the given file
data=pd.read_csv('/content/StudentsPerformance.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#1. Find out how many males and females participated in the test.
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
#2. What do you think about the students' parental level of education?

# %%
data.groupby('parental level of education').sum()
# Out:
# <ipython-input-11-44e5b50c1ff9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('parental level of education').sum()
#                              math score  reading score  writing score
# parental level of education
# associate's degree                15091          15766          15547
# bachelor's degree                  8176           8614           8659
# high school                       12117          12662          12231
# master's degree                    4145           4481           4465
# some college                      15171          15722          15602
# some high school                  11301          11950          11615

# %%
#3. Who scores the most on average for math, reading and writing based on ● Gender ● Test preparation course

# %%
gender_averagescores=data.groupby('gender').mean()
gender_avgsub=gender_averagescores[['math score','reading score','writing score']]
print(gender_avgsub)
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058
# <ipython-input-14-329ef2b8dc8a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gender_averagescores=data.groupby('gender').mean()

# %%
#4. What do you think about the scoring variation for math, reading and writing based on ● Gender ● Test preparation course

# %%
data.groupby(['gender','test preparation course']).var()
# Out:
# <ipython-input-17-337338ee36ae>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.var is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender','test preparation course']).var()
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                208.173913     161.175546     149.836897
#        none                     272.602767     214.241220     225.495172
# male   completed                197.098133     185.297987     166.098233
#        none                     205.513600     184.843553     181.394687

# %%
#5. The management needs your help to give bonus points to the top 25% of students based on their math score,so how will you help the management to achieve this.

# %%
threshold_score=data['math score'].quantile(0.75)
data['qualify_bonus']=data['math score']>=score
print(data['qualify_bonus'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: qualify_bonus, Length: 1000, dtype: bool

# %%
# finding students with more than threshold math score
top_25_percent = data[data['math score'] > threshold_score]
top_25_percent
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 430  female        group A                some college      standard
# 431  female        group B           bachelor's degree  free/reduced
# 432  female        group D           bachelor's degree      standard
# 433  female        group D                 high school      standard
# 434  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...
